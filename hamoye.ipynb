# %%
# Name: Bertram Okonkwo
# Hamoye ID: 156ea6be1981f000 

import os
os.getcwd()
# Out:
# 'C:\\Users\\lenovo\\Downloads'

# %%
# importing python libraries

import pandas as pd
import numpy as np
import mathplotlib.pylot as plt

# %%
# loading the first 10 observations

data_analysis.head(10)
# Out:
#    Area Code     Area  Item Code              Item  Element Code  \
# 0          4  Algeria       2501        Population           511
# 1          4  Algeria       2501        Population          5301
# 2          4  Algeria       2901       Grand Total           664
# 3          4  Algeria       2901       Grand Total           674
# 4          4  Algeria       2901       Grand Total           684
# 5          4  Algeria       2903  Vegetal Products           664
# 6          4  Algeria       2903  Vegetal Products           674
# 7          4  Algeria       2903  Vegetal Products           684
# 8          4  Algeria       2941   Animal Products           664
# 9          4  Algeria       2941   Animal Products           674
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# ...

# %%
# loading the last 10 observations

data_analysis.tail(10)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 60933        181  Zimbabwe       2899  Miscellaneous          5611
# 60934        181  Zimbabwe       2899  Miscellaneous          5072
# 60935        181  Zimbabwe       2899  Miscellaneous          5911
# 60936        181  Zimbabwe       2899  Miscellaneous          5301
# 60937        181  Zimbabwe       2899  Miscellaneous          5170
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit  Y2014  Y2015  \
# 60933                         Import Quantity      1000 tonnes  42.00  47.00
# ...

# %%
# finding the summary statistics of the data frame 

data_analysis = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding="latin1")
data_analysis.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
#performing a groupby on animal fat for y2014 and y2017

animal_fat_2014 = data_analysis.groupby('Item')['Y2014'].sum()
animal_fat_2017 = data_analysis.groupby('Item')['Y2017'].sum()

print(animal_fat_2014, animal_fat_2017)
# Out:
# Item
# Alcohol, Non-Food        2403.00
# Alcoholic Beverages    102410.11
# Animal Products         11935.65
# Animal fats            209460.54
# Apples and products      9499.23
#                          ...
# Vegetables, Other      155038.96
# Vegetal Products       107145.19
# Wheat and products     232670.13
# Wine                     4497.36
# Yams                   200396.96
# Name: Y2014, Length: 119, dtype: float64 Item
# Alcohol, Non-Food        2348.00
# Alcoholic Beverages     95581.06
# Animal Products         11547.65
# Animal fats            269617.53
# Apples and products     10198.90
#                          ...
# Vegetables, Other      157752.59
# Vegetal Products       107655.20
# Wheat and products     240047.62
# Wine                     4178.02
# Yams                   229174.59
# Name: Y2017, Length: 119, dtype: float64

# %%
# finding missing data

missing_data = data_analysis.isnull().sum()
missing_data_percent = data_analysis.isnull().sum()*100/ len(fao_analysis)
print(missing_data, missing_data_percent)
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64 Area Code       0.000000
# Area            0.000000
# Item Code       0.000000
# Item            0.000000
# Element Code    0.000000
# Element         0.000000
# Unit            0.000000
# Y2014           2.607354
# Y2015           2.540078
# Y2016           2.518747
# Y2017           2.471162
# Y2018           2.356300
# dtype: float64

# %%
high_corre = fao_analysis.groupby('Element Code')['Y2016'].sum()

print(high_corre)
# Out:
# Element Code
# 511     1085107.00
# 645       48985.28
# 664      451810.00
# 674       11779.69
# 684       10102.77
# 5072      33140.12
# 5123     157787.00
# 5131     280631.00
# 5142    1247022.17
# 5154      69563.68
# 5170      37224.00
# 5171         89.00
# 5301    2044842.70
# 5511    1943537.15
# 5521     228958.65
# 5527      23389.20
# 5611     286582.78
# 5911     151920.46
# Name: Y2016, dtype: float64
